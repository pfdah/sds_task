# %%
import pickle
import time
import torch
from torch.utils.data import DataLoader

from custom_dataset import CustomOCRDataset
from helper import create_data_csv
from model import TextClassificationModel, train, evaluate
from preprocess import preprocess, collate_batch

# %%
torch.manual_seed(5678)

# %%
train_dataset = preprocess()

# %%
file = open('./vocab.pkl', 'rb')
# dump information to that file
vocab = pickle.load(file)
# close the file
file.close()

# %%
vocab_size = len(vocab)
model = TextClassificationModel(vocab_size)

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset

# Hyperparameters
EPOCHS = 100  # epoch
LR = 0.1  # learning rate
BATCH_SIZE = 64  # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)

dataset = CustomOCRDataset('./train_dataset.csv')
train_iter = iter(train_dataset)
train_dataset = to_map_style_dataset(train_iter)
num_train = int(len(dataset) * 0.95)
split_train_, split_valid_ = random_split(
    train_dataset, [num_train, len(train_dataset) - num_train]
)

train_dataloader = DataLoader(
    split_train_, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)
valid_dataloader = DataLoader(
    split_valid_, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)
training_accuracy = []
validation_accuracy = []
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    accu_train = train(train_dataloader, model, optimizer, criterion, epoch)
    accu_val = evaluate(valid_dataloader, model, criterion)
    print("-" * 59)
    print("Training Accuracy: ", accu_train)
    training_accuracy.append(accu_train)
    print(
        "| end of epoch {:3d} | time: {:5.2f}s | "
        "valid accuracy {:8.3f} |".format(
            epoch, time.time() - epoch_start_time, accu_val
        )
    )
    validation_accuracy.append(accu_val)
    print("-" * 59)
# Out:
# -----------------------------------------------------------
# Training Accuracy:  0.140625
# | end of epoch   1 | time:  0.30s | valid accuracy    0.152 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.21875
# | end of epoch   2 | time:  0.28s | valid accuracy    0.152 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.328125
# | end of epoch   3 | time:  0.29s | valid accuracy    0.152 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.28125
# | end of epoch   4 | time:  0.28s | valid accuracy    0.152 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.15625
# | end of epoch   5 | time:  0.29s | valid accuracy    0.264 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.390625
# | end of epoch   6 | time:  0.29s | valid accuracy    0.296 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.40625
# | end of epoch   7 | time:  0.29s | valid accuracy    0.296 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.28125
# | end of epoch   8 | time:  0.29s | valid accuracy    0.328 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.390625
# | end of epoch   9 | time:  0.29s | valid accuracy    0.360 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.375
# | end of epoch  10 | time:  0.29s | valid accuracy    0.272 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.3125
# | end of epoch  11 | time:  0.29s | valid accuracy    0.280 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.296875
# | end of epoch  12 | time:  0.28s | valid accuracy    0.304 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.375
# | end of epoch  13 | time:  0.29s | valid accuracy    0.392 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.40625
# | end of epoch  14 | time:  0.29s | valid accuracy    0.376 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.40625
# | end of epoch  15 | time:  0.29s | valid accuracy    0.320 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.390625
# | end of epoch  16 | time:  0.28s | valid accuracy    0.280 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.515625
# | end of epoch  17 | time:  0.29s | valid accuracy    0.256 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.28125
# | end of epoch  18 | time:  0.29s | valid accuracy    0.264 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.34375
# | end of epoch  19 | time:  0.29s | valid accuracy    0.296 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.390625
# | end of epoch  20 | time:  0.29s | valid accuracy    0.368 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.515625
# | end of epoch  21 | time:  0.29s | valid accuracy    0.400 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0
|
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.953125
# | end of epoch  67 | time:  0.29s | valid accuracy    0.720 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  68 | time:  0.34s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.90625
# | end of epoch  69 | time:  0.30s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  70 | time:  0.31s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.859375
# | end of epoch  71 | time:  0.30s | valid accuracy    0.720 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.828125
# | end of epoch  72 | time:  0.31s | valid accuracy    0.720 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  73 | time:  0.30s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.859375
# | end of epoch  74 | time:  0.30s | valid accuracy    0.744 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  75 | time:  0.30s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.90625
# | end of epoch  76 | time:  0.31s | valid accuracy    0.736 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  77 | time:  0.30s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.90625
# | end of epoch  78 | time:  0.30s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.859375
# | end of epoch  79 | time:  0.30s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.953125
# | end of epoch  80 | time:  0.31s | valid accuracy    0.768 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  81 | time:  0.30s | valid accuracy    0.760 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.84375
# | end of epoch  82 | time:  0.31s | valid accuracy    0.736 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.84375
# | end of epoch  83 | time:  0.31s | valid accuracy    0.768 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  84 | time:  0.31s | valid accuracy    0.768 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.9375
# | end of epoch  85 | time:  0.30s | valid accuracy    0.784 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  86 | time:  0.29s | valid accuracy    0.776 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  87 | time:  0.30s | valid accuracy    0.784 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.921875
# | end of epoch  88 | time:  0.30s | valid accuracy    0.744 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  89 | time:  0.30s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.90625
# | end of epoch  90 | time:  0.29s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.9375
# | end of epoch  91 | time:  0.30s | valid accuracy    0.760 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.90625
# | end of epoch  92 | time:  0.29s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  93 | time:  0.29s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  94 | time:  0.30s | valid accuracy    0.712 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.875
# | end of epoch  95 | time:  0.30s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.921875
# | end of epoch  96 | time:  0.30s | valid accuracy    0.744 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.9375
# | end of epoch  97 | time:  0.29s | valid accuracy    0.752 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.953125
# | end of epoch  98 | time:  0.29s | valid accuracy    0.720 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch  99 | time:  0.29s | valid accuracy    0.728 |
# -----------------------------------------------------------
# -----------------------------------------------------------
# Training Accuracy:  0.890625
# | end of epoch 100 | time:  0.29s | valid accuracy    0.720 |
# -----------------------------------------------------------

# %%
torch.save(model,'./model/trained_model.pth')

# %%
# Load the saved model
loaded_model = torch.load('./model/trained_model.pth')
loaded_model.eval()  # Set the model to evaluation mode if needed
# Out:
# TextClassificationModel(
#   (embedding): EmbeddingBag(106256, 64, mode='mean')
#   (fc): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU(inplace=True)
#   (fc2): Linear(in_features=10, out_features=5, bias=True)
#   (relu2): ReLU(inplace=True)
#   (fc3): Linear(in_features=5, out_features=2, bias=True)
#   (fc4): Linear(in_features=2, out_features=5, bias=True)
# )

# %%
test_dataset = CustomOCRDataset('./test_dataset.csv')
test_iter = iter(test_dataset)
test_dataset = to_map_style_dataset(test_iter)

# %%
valid_dataloader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)

# %%
l = enumerate(valid_dataloader)
